# %%
pip install stanfordnlp
# Out:
# Collecting stanfordnlp
#   Downloading https://files.pythonhosted.org/packages/41/bf/5d2898febb6e993fcccd90484cba3c46353658511a41430012e901824e94/stanfordnlp-0.2.0-py3-none-any.whl (158kB)
#      |████████████████████████████████| 163kB 5.0MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from stanfordnlp) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from stanfordnlp) (2.21.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from stanfordnlp) (1.16.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from stanfordnlp) (3.7.1)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from stanfordnlp) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->stanfordnlp) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->stanfordnlp) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->stanfordnlp) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->stanfordnlp) (2.8)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf->stanfordnlp) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->stanfordnlp) (41.0.1)
# Installing collected packages: stanfordnlp
# Successfully installed stanfordnlp-0.2.0

# %%
import stanfordnlp

# %%
stanfordnlp.download('hi')
# Out:
# Using the default treebank "hi_hdtb" for language "hi".
# Would you like to download the models for: hi_hdtb now? (Y/n)
# Y
#
# Default download directory: /root/stanfordnlp_resources
# Hit enter to continue or type an alternate directory.
#
#
# Downloading models for: hi_hdtb
# Download location: /root/stanfordnlp_resources/hi_hdtb_models.zip
# 100%|██████████| 208M/208M [00:25<00:00, 7.43MB/s]
# Download complete.  Models saved to: /root/stanfordnlp_resources/hi_hdtb_models.zip
# Extracting models file for: hi_hdtb
# Cleaning up...Done.

# %%
nlp = stanfordnlp.Pipeline(lang="hi")
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/root/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_tokenizer.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/root/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_tagger.pt', 'pretrain_path': '/root/stanfordnlp_resources/hi_hdtb_models/hi_hdtb.pretrain.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/root/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_lemmatizer.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/root/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_parser.pt', 'pretrain_path': '/root/stanfordnlp_resources/hi_hdtb_models/hi_hdtb.pretrain.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
import pandas as pd

#extract lemma
def extract_lemma(doc):
    parsed_text = {'word':[], 'lemma':[]}
    for sent in doc.sentences:
        for wrd in sent.words:
            #extract text and lemma
            parsed_text['word'].append(wrd.text)
            parsed_text['lemma'].append(wrd.lemma)
    #return a dataframe
    return pd.DataFrame(parsed_text)

# %%
pos_dict = {
'CC': 'coordinating conjunction','CD': 'cardinal digit','DT': 'determiner',
'EX': 'existential there (like: \"there is\" ... think of it like \"there exists\")',
'FW': 'foreign word','IN':  'preposition/subordinating conjunction','JJ': 'adjective \'big\'',
'JJR': 'adjective, comparative \'bigger\'','JJS': 'adjective, superlative \'biggest\'',
'LS': 'list marker 1)','MD': 'modal could, will','NN': 'noun, singular \'desk\'',
'NNS': 'noun plural \'desks\'','NNP': 'proper noun, singular \'Harrison\'',
'NNPS': 'proper noun, plural \'Americans\'','PDT': 'predeterminer \'all the kids\'',
'POS': 'possessive ending parent\'s','PRP': 'personal pronoun I, he, she',
'PRP$': 'possessive pronoun my, his, hers','RB': 'adverb very, silently,',
'RBR': 'adverb, comparative better','RBS': 'adverb, superlative best',
'RP': 'particle give up','TO': 'to go \'to\' the store.','UH': 'interjection errrrrrrrm',
'VB': 'verb, base form take','VBD': 'verb, past tense took',
'VBG': 'verb, gerund/present participle taking','VBN': 'verb, past participle taken',
'VBP': 'verb, sing. present, non-3d take','VBZ': 'verb, 3rd person sing. present takes',
'WDT': 'wh-determiner which','WP': 'wh-pronoun who, what','WP$': 'possessive wh-pronoun whose',
'WRB': 'wh-abverb where, when','QF' : 'quantifier, bahut, thoda, kam (Hindi)','VM' : 'main verb',
'PSP' : 'postposition, common in indian langs','DEM' : 'demonstrative, common in indian langs'
}

#extract parts of speech
def extract_pos(doc):
    parsed_text = {'word':[], 'pos':[], 'exp':[]}
    for sent in doc.sentences:
        for wrd in sent.words:
            if wrd.pos in pos_dict.keys():
                pos_exp = pos_dict[wrd.pos]
            else:
                pos_exp = 'NA'
            parsed_text['word'].append(wrd.text)
            parsed_text['pos'].append(wrd.pos)
            parsed_text['exp'].append(pos_exp)
    #return a dataframe of pos and text
    return pd.DataFrame(parsed_text)

# %%
hindi_doc = nlp("""केंद्र की मोदी सरकार ने शुक्रवार को अपना अंतरिम बजट पेश किया. कार्यवाहक वित्त मंत्री पीयूष गोयल ने अपने बजट में किसान, मजदूर, करदाता, महिला वर्ग समेत हर किसी के लिए बंपर ऐलान किए. हालांकि, बजट के बाद भी टैक्स को लेकर काफी कन्फ्यूजन बना रहा. केंद्र सरकार के इस अंतरिम बजट क्या खास रहा और किसको क्या मिला, आसान भाषा में यहां समझें""")

# %%
extract_pos(hindi_doc)
# Out:
#          word   pos                                    exp
# 0      केंद्र   NNP       proper noun, singular 'Harrison'
# 1          की   PSP   postposition, common in indian langs
# 2        मोदी   NNP       proper noun, singular 'Harrison'
# 3       सरकार    NN                  noun, singular 'desk'
# 4          ने   PSP   postposition, common in indian langs
# 5    शुक्रवार   NNP       proper noun, singular 'Harrison'
# 6          को   PSP   postposition, common in indian langs
# 7        अपना   PRP            personal pronoun I, he, she
# 8      अंतरिम    JJ                        adjective 'big'
# 9         बजट    NN                  noun, singular 'desk'
# 10        पेश    JJ                        adjective 'big'
# 11       किया    VM                              main verb
# 12          .   SYM                                     NA
# 13  कार्यवाहक    JJ                        adjective 'big'
# 14      वित्त  NNPC                                     NA
# 15     मंत्री   NNP       proper noun, singular 'Harrison'
# 16      पीयूष  NNPC                                     NA
# 17       गोयल   NNP       proper noun, singular 'Harrison'
# 18         ने   PSP   postposition, common in indian langs
# 19       अपने   PRP            personal pronoun I, he, she
# 20        बजट    NN                  noun, singular 'desk'
# 21        में   PSP   postposition, common in indian langs
# 22      किसान    NN                  noun, singular 'desk'
# 23          ,   SYM                                     NA
# 24      मजदूर    NN                  noun, singular 'desk'
# 25          ,   SYM                                     NA
# 26     करदाता    NN                  noun, singular 'desk'
# 27          ,   SYM                                     NA
# 28      महिला   NNC                                     NA
# 29       वर्ग    NN                  noun, singular 'desk'
# ..        ...   ...                                    ...
# 42         के   PSP   postposition, common in indian langs
# 43        बाद   NST                                     NA
# 44         भी    RP                       particle give up
# 45      टैक्स    NN                  noun, singular 'desk'
# 46         को   PSP   postposition, common in indian langs
# 47       लेकर    VM                              main verb
# 48       काफी    QF  quantifier, bahut, thoda, kam (Hindi)
# 49  कन्फ्यूजन    NN                  noun, singular 'desk'
# 50        बना    VM                              main verb
# 51        रहा  VAUX                                     NA
# 52          .   SYM                                     NA
# 53     केंद्र  NNPC                                     NA
# 54      सरकार   NNP       proper noun, singular 'Harrison'
# 55         के   PSP   postposition, common in indian langs
# 56         इस   DEM  demonstrative, common in indian langs
# 57     अंतरिम    JJ                        adjective 'big'
# 58        बजट    NN                  noun, singular 'desk'
# 59       क्या    WQ                                     NA
# 60        खास    JJ                        adjective 'big'
# 61        रहा    VM                              main verb
# 62         और    CC               coordinating conjunction
# 63      किसको   PRP            personal pronoun I, he, she
# 64       क्या    WQ                                     NA
# 65       मिला    VM                              main verb
# 66          ,   SYM                                     NA
# 67       आसान    JJ                        adjective 'big'
# 68       भाषा    NN                  noun, singular 'desk'
# 69        में   PSP   postposition, common in indian langs
# 70       यहां   PRP            personal pronoun I, he, she
# 71      समझें    VM                              main verb
#
# [72 rows x 3 columns]

# %%
import pandas as pd

#extract lemma
def extract_lemma(doc):
    parsed_text = {'word':[], 'lemma':[]}
    for sent in doc.sentences:
        for wrd in sent.words:
            #extract text and lemma
            parsed_text['word'].append(wrd.text)
            parsed_text['lemma'].append(wrd.lemma)
    #return a dataframe
    return pd.DataFrame(parsed_text)

#call the function on doc
extract_lemma(hindi_doc)
# Out:
#          word      lemma
# 0      केंद्र     केंद्र
# 1          की         का
# 2        मोदी       मोदी
# 3       सरकार      सरकार
# 4          ने         ने
# 5    शुक्रवार   शुक्रवार
# 6          को         को
# 7        अपना       अपना
# 8      अंतरिम     अंतरिम
# 9         बजट        बजट
# 10        पेश        पेश
# 11       किया         कर
# 12          .          .
# 13  कार्यवाहक  कार्यवाहक
# 14      वित्त      वित्त
# 15     मंत्री     मंत्री
# 16      पीयूष      पीयूष
# 17       गोयल       गोयल
# 18         ने         ने
# 19       अपने       अपना
# 20        बजट        बजट
# 21        में        में
# 22      किसान      किसान
# 23          ,      COMMA
# 24      मजदूर      मजदूर
# 25          ,      COMMA
# 26     करदाता     करदाता
# 27          ,      COMMA
# 28      महिला      महिला
# 29       वर्ग       वर्ग
# ..        ...        ...
# 42         के         का
# 43        बाद        बाद
# 44         भी         भी
# 45      टैक्स      टैक्स
# 46         को         को
# 47       लेकर         ले
# 48       काफी       काफी
# 49  कन्फ्यूजन  कन्फ्यूजन
# 50        बना         बन
# 51        रहा         रह
# 52          .          .
# 53     केंद्र     केंद्र
# 54      सरकार      सरकार
# 55         के         का
# 56         इस         यह
# 57     अंतरिम     अंतरिम
# 58        बजट        बजट
# 59       क्या       क्या
# 60        खास        खास
# 61        रहा         रह
# 62         और         और
# 63      किसको        कौन
# 64       क्या       क्या
# 65       मिला        मिल
# 66          ,      COMMA
# 67       आसान       आसान
# 68       भाषा       भाषा
# 69        में        में
# 70       यहां       यहाँ
# 71      समझें        समझ
#
# [72 rows x 2 columns]

# %%
doc = nlp("""केंद्र की मोदी सरकार ने शुक्रवार को अपना अंतरिम बजट पेश किया. कार्यवाहक वित्त मंत्री पीयूष गोयल ने अपने बजट में किसान, मजदूर, करदाता, महिला वर्ग समेत हर किसी के लिए बंपर ऐलान किए. हालांकि, बजट के बाद भी टैक्स को लेकर काफी कन्फ्यूजन बना रहा. केंद्र सरकार के इस अंतरिम बजट क्या खास रहा और किसको क्या मिला, आसान भाषा में यहां समझें""")
print(*[f'token: {token.text.ljust(9)}\t\twords: {token.words}' for sent in doc.sentences for token in sent.tokens], sep='\n')
print('')
print(*[f'word: {word.text.ljust(9)}\t\ttoken parent:{word.parent_token.index+"-"+word.parent_token.text}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# token: केंद्र   		words: [<Word index=1;text=केंद्र;lemma=केंद्र;upos=PROPN;xpos=NNP;feats=Case=Acc|Gender=Masc|Number=Sing|Person=3;governor=4;dependency_relation=nmod>]
# token: की       		words: [<Word index=2;text=की;lemma=का;upos=ADP;xpos=PSP;feats=AdpType=Post|Case=Acc|Gender=Fem|Number=Sing;governor=1;dependency_relation=case>]
# token: मोदी     		words: [<Word index=3;text=मोदी;lemma=मोदी;upos=PROPN;xpos=NNP;feats=Case=Nom|Number=Sing|Person=3;governor=4;dependency_relation=nmod>]
# token: सरकार    		words: [<Word index=4;text=सरकार;lemma=सरकार;upos=NOUN;xpos=NN;feats=Case=Acc|Gender=Fem|Number=Sing|Person=3;governor=12;dependency_relation=nsubj>]
# token: ने       		words: [<Word index=5;text=ने;lemma=ने;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=4;dependency_relation=case>]
# token: शुक्रवार 		words: [<Word index=6;text=शुक्रवार;lemma=शुक्रवार;upos=PROPN;xpos=NNP;feats=Case=Acc|Gender=Masc|Number=Sing|Person=3;governor=12;dependency_relation=obl>]
# token: को       		words: [<Word index=7;text=को;lemma=को;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=6;dependency_relation=case>]
# token: अपना     		words: [<Word index=8;text=अपना;lemma=अपना;upos=PRON;xpos=PRP;feats=Case=Nom|Gender=Masc|Number=Sing|PronType=Prs;governor=10;dependency_relation=nmod>]
# token: अंतरिम   		words: [<Word index=9;text=अंतरिम;lemma=अंतरिम;upos=ADJ;xpos=JJ;feats=Case=Nom;governor=10;dependency_relation=amod>]
# token: बजट      		words: [<Word index=10;text=बजट;lemma=बजट;upos=NOUN;xpos=NN;feats=Case=Nom|Gender=Masc|Number=Sing|Person=3;governor=12;dependency_relation=obj>]
# token: पेश      		words: [<Word index=11;text=पेश;lemma=पेश;upos=ADJ;xpos=JJ;feats=_;governor=12;dependency_relation=compound>]
# token: किया     		words: [<Word index=12;text=किया;lemma=कर;upos=VERB;xpos=VM;feats=Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Act;governor=0;dependency_relation=root>]
# token: .        		words: [<Word index=13;text=.;lemma=.;upos=PUNCT;xpos=SYM;feats=_;governor=12;dependency_relation=punct>]
# token: कार्यवाहक		words: [<Word index=1;text=कार्यवाहक;lemma=कार्यवाहक;upos=ADJ;xpos=JJ;feats=Case=Acc;governor=3;dependency_relation=amod>]
# token: वित्त    		words: [<Word index=2;text=वित्त;lemma=वित्त;upos=PROPN;xpos=NNPC;feats=Case=Nom|Gender=Masc|Number=Sing|Person=3;governor=3;dependency_relation=compound>]
# token: मंत्री   		words: [<Word index=3;text=मंत्री;lemma=मंत्री;upos=PROPN;xpos=NNP;feats=Case=Nom|Gender=Masc|Number=Sing|Person=3;governor=5;dependency_relation=nmod>]
# token: पीयूष    		words: [<Word index=4;text=पीयूष;lemma=पीयूष;upos=PROPN;xpos=NNPC;feats=Case=Nom|Gender=Fem|Number=Sing|Person=3;governor=5;dependency_relation=compound>]
# token: गोयल     		words: [<Word index=5;text=गोयल;lemma=गोयल;upos=PROPN;xpos=NNP;feats=Case=Acc|Number=Sing|Person=3;governor=25;dependency_relation=nsubj>]
# token: ने       		words: [<Word index=6;text=ने;lemma=ने;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=5;dependency_relation=case>]
# token: अपने     		words: [<Word index=7;text=अपने;lemma=अपना;upos=PRON;xpos=PRP;feats=Case=Acc|Gender=Masc|PronType=Prs;governor=8;dependency_relation=nmod>]
# token: बजट      		words: [<Word index=8;text=बजट;lemma=बजट;upos=NOUN;xpos=NN;feats=Case=Acc|Gender=Masc|Number=Sing|Person=3;governor=25;dependency_relation=obl>]
# token: में      		words: [<Word index=9;text=में;lemma=में;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=8;dependency_relation=case>]
# token: किसान    		words: [<Word index=10;text=किसान;lemma=किसान;upos=NOUN;xpos=NN;feats=Case=Acc|Gender=Masc|Number=Sing|Person=3;governor=25;dependency_relation=obl>]
# token: ,        		words: [<Word index=11;text=,;lemma=COMMA;upos=PUNCT;xpos=SYM;feats=_;governor=12;dependency_relation=punct>]
# token: मजदूर    		words: [<Word index=12;text=मजदूर;lemma=मजदूर;upos=NOUN;xpos=NN;feats=Case=Acc|Gender=Masc|Number=Sing|Person=3;governor=10;dependency_relation=conj>]
# token: ,        		words: [<Word index=13;text=,;lemma=COMMA;upos=PUNCT;xpos=SYM;feats=_;governor=14;dependency_relation=punct>]
# token: करदाता   		words: [<Word index=14;text=करदाता;lemma=करदाता;upos=NOUN;xpos=NN;feats=Case=Acc|Gender=Masc|Number=Sing|Person=3;governor=10;dependency_relation=conj>]
# token: ,        		words: [<Word index=15;text=,;lemma=COMMA;upos=PUNCT;xpos=SYM;feats=_;governor=17;dependency_relation=cc>]
# token: महिला    		words: [<Word index=16;text=महिला;lemma=महिला;upos=NOUN;xpos=NNC;feats=Case=Nom|Gender=Fem|Number=Sing|Person=3;governor=17;dependency_relation=compound>]
# token: वर्ग     		words: [<Word index=17;text=वर्ग;lemma=वर्ग;upos=NOUN;xpos=NN;feats=Case=Acc|Gender=Masc|Number=Sing|Person=3;governor=10;dependency_relation=conj>]
# token: समेत     		words: [<Word index=18;text=समेत;lemma=समेत;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=17;dependency_relation=case>]
# token: हर       		words: [<Word index=19;text=हर;lemma=हर;upos=DET;xpos=QF;feats=PronType=Ind;governor=20;dependency_relation=det>]
# token: किसी     		words: [<Word index=20;text=किसी;lemma=कोई;upos=PRON;xpos=PRP;feats=Case=Acc|Number=Sing|Person=3|PronType=Prs;governor=25;dependency_relation=obl>]
# token: के       		words: [<Word index=21;text=के;lemma=का;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=20;dependency_relation=case>]
# token: लिए      		words: [<Word index=22;text=लिए;lemma=लिए;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=20;dependency_relation=case>]
# token: बंपर     		words: [<Word index=23;text=बंपर;lemma=बंपर;upos=ADJ;xpos=JJ;feats=Case=Nom;governor=24;dependency_relation=amod>]
# token: ऐलान     		words: [<Word index=24;text=ऐलान;lemma=ऐलान;upos=NOUN;xpos=NN;feats=Case=Nom|Gender=Masc|Number=Plur|Person=3;governor=25;dependency_relation=compound>]
# token: किए      		words: [<Word index=25;text=किए;lemma=कर;upos=VERB;xpos=VM;feats=Aspect=Perf|Gender=Masc|Number=Plur|VerbForm=Part|Voice=Act;governor=0;dependency_relation=root>]
# token: .        		words: [<Word index=26;text=.;lemma=.;upos=PUNCT;xpos=SYM;feats=_;governor=25;dependency_relation=punct>]
# token: हालांकि  		words: [<Word index=1;text=हालांकि;lemma=हालांकि;upos=SCONJ;xpos=CC;feats=_;governor=12;dependency_relation=mark>]
# token: ,        		words: [<Word index=2;text=,;lemma=COMMA;upos=PUNCT;xpos=SYM;feats=_;governor=1;dependency_relation=punct>]
# token: बजट      		words: [<Word index=3;text=बजट;lemma=बजट;upos=NOUN;xpos=NN;feats=Case=Acc|Gender=Masc|Number=Sing|Person=3;governor=12;dependency_relation=obl>]
# token: के       		words: [<Word index=4;text=के;lemma=का;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=3;dependency_relation=case>]
# token: बाद      		words: [<Word index=5;text=बाद;lemma=बाद;upos=ADP;xpos=NST;feats=AdpType=Post|Case=Nom|Gender=Masc|Number=Sing|Person=3;governor=3;dependency_relation=case>]
# token: भी       		words: [<Word index=6;text=भी;lemma=भी;upos=PART;xpos=RP;feats=_;governor=5;dependency_relation=dep>]
# token: टैक्स    		words: [<Word index=7;text=टैक्स;lemma=टैक्स;upos=NOUN;xpos=NN;feats=Case=Acc|Gender=Masc|Number=Sing|Person=3;governor=9;dependency_relation=obj>]
# token: को       		words: [<Word index=8;text=को;lemma=को;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=7;dependency_relation=case>]
# token: लेकर     		words: [<Word index=9;text=लेकर;lemma=ले;upos=VERB;xpos=VM;feats=VerbForm=Conv;governor=12;dependency_relation=advcl>]
# token: काफी     		words: [<Word index=10;text=काफी;lemma=काफी;upos=DET;xpos=QF;feats=PronType=Ind;governor=11;dependency_relation=det>]
# token: कन्फ्यूजन		words: [<Word index=11;text=कन्फ्यूजन;lemma=कन्फ्यूजन;upos=NOUN;xpos=NN;feats=Case=Nom|Gender=Masc|Number=Sing|Person=3;governor=12;dependency_relation=nsubj>]
# token: बना      		words: [<Word index=12;text=बना;lemma=बन;upos=VERB;xpos=VM;feats=Aspect=Perf|Gender=Masc|Number=Sing|Person=3|VerbForm=Part|Voice=Act;governor=0;dependency_relation=root>]
# token: रहा      		words: [<Word index=13;text=रहा;lemma=रह;upos=AUX;xpos=VAUX;feats=Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part;governor=12;dependency_relation=aux>]
# token: .        		words: [<Word index=14;text=.;lemma=.;upos=PUNCT;xpos=SYM;feats=_;governor=12;dependency_relation=punct>]
# token: केंद्र   		words: [<Word index=1;text=केंद्र;lemma=केंद्र;upos=PROPN;xpos=NNPC;feats=Case=Nom|Gender=Masc|Number=Sing|Person=3;governor=2;dependency_relation=compound>]
# token: सरकार    		words: [<Word index=2;text=सरकार;lemma=सरकार;upos=PROPN;xpos=NNP;feats=Case=Acc|Gender=Fem|Number=Sing|Person=3;governor=6;dependency_relation=nmod>]
# token: के       		words: [<Word index=3;text=के;lemma=का;upos=ADP;xpos=PSP;feats=AdpType=Post|Case=Acc|Gender=Masc|Number=Sing;governor=2;dependency_relation=case>]
# token: इस       		words: [<Word index=4;text=इस;lemma=यह;upos=DET;xpos=DEM;feats=Case=Acc|Number=Sing|Person=3|PronType=Dem;governor=6;dependency_relation=det>]
# token: अंतरिम   		words: [<Word index=5;text=अंतरिम;lemma=अंतरिम;upos=ADJ;xpos=JJ;feats=Case=Nom;governor=6;dependency_relation=amod>]
# token: बजट      		words: [<Word index=6;text=बजट;lemma=बजट;upos=NOUN;xpos=NN;feats=Case=Nom|Gender=Masc|Number=Sing|Person=3;governor=9;dependency_relation=nsubj>]
# token: क्या     		words: [<Word index=7;text=क्या;lemma=क्या;upos=PRON;xpos=WQ;feats=PronType=Int;governor=9;dependency_relation=advmod>]
# token: खास      		words: [<Word index=8;text=खास;lemma=खास;upos=ADJ;xpos=JJ;feats=_;governor=9;dependency_relation=xcomp>]
# token: रहा      		words: [<Word index=9;text=रहा;lemma=रह;upos=VERB;xpos=VM;feats=Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Act;governor=0;dependency_relation=root>]
# token: और       		words: [<Word index=10;text=और;lemma=और;upos=CCONJ;xpos=CC;feats=_;governor=13;dependency_relation=cc>]
# token: किसको    		words: [<Word index=11;text=किसको;lemma=कौन;upos=PRON;xpos=PRP;feats=Case=Nom|Number=Sing|Person=3|PronType=Prs;governor=13;dependency_relation=nsubj>]
# token: क्या     		words: [<Word index=12;text=क्या;lemma=क्या;upos=PRON;xpos=WQ;feats=PronType=Int;governor=13;dependency_relation=advmod>]
# token: मिला     		words: [<Word index=13;text=मिला;lemma=मिल;upos=VERB;xpos=VM;feats=Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Act;governor=9;dependency_relation=conj>]
# token: ,        		words: [<Word index=14;text=,;lemma=COMMA;upos=PUNCT;xpos=SYM;feats=_;governor=13;dependency_relation=punct>]
# token: आसान     		words: [<Word index=15;text=आसान;lemma=आसान;upos=ADJ;xpos=JJ;feats=Case=Acc;governor=16;dependency_relation=amod>]
# token: भाषा     		words: [<Word index=16;text=भाषा;lemma=भाषा;upos=NOUN;xpos=NN;feats=Case=Acc|Gender=Fem|Number=Sing|Person=3;governor=19;dependency_relation=obl>]
# token: में      		words: [<Word index=17;text=में;lemma=में;upos=ADP;xpos=PSP;feats=AdpType=Post;governor=16;dependency_relation=case>]
# token: यहां     		words: [<Word index=18;text=यहां;lemma=यहाँ;upos=PRON;xpos=PRP;feats=Case=Nom|PronType=Prs;governor=19;dependency_relation=obl>]
# token: समझें    		words: [<Word index=19;text=समझें;lemma=समझ;upos=VERB;xpos=VM;feats=Mood=Sub|Number=Sing|Person=3|VerbForm=Fin|Voice=Act;governor=9;dependency_relation=conj>]
#
# word: केंद्र   		token parent:1-केंद्र
# word: की       		token parent:2-की
# word: मोदी     		token parent:3-मोदी
# word: सरकार    		token parent:4-सरकार
# word: ने       		token parent:5-ने
# word: शुक्रवार 		token parent:6-शुक्रवार
# word: को       		token parent:7-को
# word: अपना     		token parent:8-अपना
# word: अंतरिम   		token parent:9-अंतरिम
# word: बजट      		token parent:10-बजट
# word: पेश      		token parent:11-पेश
# word: किया     		token parent:12-किया
# word: .        		token parent:13-.
# word: कार्यवाहक		token parent:1-कार्यवाहक
# word: वित्त    		token parent:2-वित्त
# word: मंत्री   		token parent:3-मंत्री
# word: पीयूष    		token parent:4-पीयूष
# word: गोयल     		token parent:5-गोयल
# word: ने       		token parent:6-ने
# word: अपने     		token parent:7-अपने
# word: बजट      		token parent:8-बजट
# word: में      		token parent:9-में
# word: किसान    		token parent:10-किसान
# word: ,        		token parent:11-,
# word: मजदूर    		token parent:12-मजदूर
# word: ,        		token parent:13-,
# word: करदाता   		token parent:14-करदाता
# word: ,        		token parent:15-,
# word: महिला    		token parent:16-महिला
# word: वर्ग     		token parent:17-वर्ग
# word: समेत     		token parent:18-समेत
# word: हर       		token parent:19-हर
# word: किसी     		token parent:20-किसी
# word: के       		token parent:21-के
# word: लिए      		token parent:22-लिए
# word: बंपर     		token parent:23-बंपर
# word: ऐलान     		token parent:24-ऐलान
# word: किए      		token parent:25-किए
# word: .        		token parent:26-.
# word: हालांकि  		token parent:1-हालांकि
# word: ,        		token parent:2-,
# word: बजट      		token parent:3-बजट
# word: के       		token parent:4-के
# word: बाद      		token parent:5-बाद
# word: भी       		token parent:6-भी
# word: टैक्स    		token parent:7-टैक्स
# word: को       		token parent:8-को
# word: लेकर     		token parent:9-लेकर
# word: काफी     		token parent:10-काफी
# word: कन्फ्यूजन		token parent:11-कन्फ्यूजन
# word: बना      		token parent:12-बना
# word: रहा      		token parent:13-रहा
# word: .        		token parent:14-.
# word: केंद्र   		token parent:1-केंद्र
# word: सरकार    		token parent:2-सरकार
# word: के       		token parent:3-के
# word: इस       		token parent:4-इस
# word: अंतरिम   		token parent:5-अंतरिम
# word: बजट      		token parent:6-बजट
# word: क्या     		token parent:7-क्या
# word: खास      		token parent:8-खास
# word: रहा      		token parent:9-रहा
# word: और       		token parent:10-और
# word: किसको    		token parent:11-किसको
# word: क्या     		token parent:12-क्या
# word: मिला     		token parent:13-मिला
# word: ,        		token parent:14-,
# word: आसान     		token parent:15-आसान
# word: भाषा     		token parent:16-भाषा
# word: में      		token parent:17-में
# word: यहां     		token parent:18-यहां
# word: समझें    		token parent:19-समझें
